# %%
# %matplotlib widget

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Bank-1 Pawley Refinement

# %%
with open("./dia_bank_1_x_ycalc.dat", "r") as f:
    x, y_calc = np.loadtxt(f, unpack=True)
with open("./dia_bank_1_x_yobs.dat", "r") as f:
    x, y_obs = np.loadtxt(f, unpack=True)

y_diff = y_calc - y_obs - 10000
    
fig, ax = plt.subplots(figsize=(12, 8))
ax.plot(x, y_obs, 'bo', markersize=5, label="Yobs")
ax.plot(x, y_calc, 'r-', linewidth=3, label="Ycalc")
ax.plot(x, y_diff, 'g-', linewidth=3, label="Diff")

from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1, 1)) 
ax.yaxis.set_major_formatter(formatter)

ax.set_xlabel(r'TOF ($\mu s$)', fontsize=25)
ax.set_ylabel('Int. (a.u.)', fontsize=25)
ax.set_xlim([800, 6000])
ax.set_xticks(np.arange(800, 6400, 800), fontsize=23)
ax.tick_params(axis='x', labelsize=20, length=10)
# ax.set_yticks(np.arange(0.5, 2.2, 0.2), fontsize=23)
ax.yaxis.offsetText.set_fontsize(20)
ax.tick_params(axis='y', labelsize=20, length=10)
ax.legend(loc='upper left', bbox_to_anchor=(0.02, 0.98), frameon=False, fontsize="xx-large")
plt.tight_layout()
fig.canvas.header_visible = False
plt.show()
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %% [markdown]
# # Bank-2 Pawley Refinement

# %%
with open("./dia_bank_2_x_ycalc.dat", "r") as f:
    x, y_calc = np.loadtxt(f, unpack=True)
with open("./dia_bank_2_x_yobs.dat", "r") as f:
    x, y_obs = np.loadtxt(f, unpack=True)

y_diff = y_calc - y_obs - 10000
    
fig, ax = plt.subplots(figsize=(12, 8))
ax.plot(x, y_obs, 'bo', markersize=5, label="Yobs")
ax.plot(x, y_calc, 'r-', linewidth=3, label="Ycalc")
ax.plot(x, y_diff, 'g-', linewidth=3, label="Diff")

from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1, 1)) 
ax.yaxis.set_major_formatter(formatter)

ax.set_xlabel(r'TOF ($\mu s$)', fontsize=25)
ax.set_ylabel('Int. (a.u.)', fontsize=25)
ax.set_xlim([800, 8000])
ax.set_xticks(np.arange(800, 8800, 800), fontsize=23)
ax.tick_params(axis='x', labelsize=20, length=10)
# ax.set_yticks(np.arange(0.5, 2.2, 0.2), fontsize=23)
ax.yaxis.offsetText.set_fontsize(20)
ax.tick_params(axis='y', labelsize=20, length=10)
ax.legend(loc='upper left', bbox_to_anchor=(0.02, 0.98), frameon=False, fontsize="xx-large")
plt.tight_layout()
fig.canvas.header_visible = False
plt.show()
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %% [markdown]
# # Bank-3 Pawley Refinement

# %%
with open("./dia_bank_3_x_ycalc.dat", "r") as f:
    x, y_calc = np.loadtxt(f, unpack=True)
with open("./dia_bank_3_x_yobs.dat", "r") as f:
    x, y_obs = np.loadtxt(f, unpack=True)

y_diff = y_calc - y_obs - 100000
    
fig, ax = plt.subplots(figsize=(12, 8))
ax.plot(x, y_obs, 'bo', markersize=5, label="Yobs")
ax.plot(x, y_calc, 'r-', linewidth=3, label="Ycalc")
ax.plot(x, y_diff, 'g-', linewidth=3, label="Diff")

from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1, 1)) 
ax.yaxis.set_major_formatter(formatter)

ax.set_xlabel(r'TOF ($\mu s$)', fontsize=25)
ax.set_ylabel('Int. (a.u.)', fontsize=25)
ax.set_xlim([800, 16000])
ax.set_xticks(np.arange(800, 16800, 1500), fontsize=23)
ax.tick_params(axis='x', labelsize=20, length=10)
# ax.set_yticks(np.arange(0.5, 2.2, 0.2), fontsize=23)
ax.yaxis.offsetText.set_fontsize(20)
ax.tick_params(axis='y', labelsize=20, length=10)
ax.legend(loc='upper left', bbox_to_anchor=(0.02, 0.98), frameon=False, fontsize="xx-large")
plt.tight_layout()
fig.canvas.header_visible = False
plt.show()
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %% [markdown]
# # Bank-4 Pawley Refinement

# %%
with open("./dia_bank_4_x_ycalc.dat", "r") as f:
    x, y_calc = np.loadtxt(f, unpack=True)
with open("./dia_bank_4_x_yobs.dat", "r") as f:
    x, y_obs = np.loadtxt(f, unpack=True)

y_diff = y_calc - y_obs - 2E5

fig, ax = plt.subplots(figsize=(12, 8))
ax.plot(x, y_obs, 'bo', markersize=5, label="Yobs")
ax.plot(x, y_calc, 'r-', linewidth=3, label="Ycalc")
ax.plot(x, y_diff, 'g-', linewidth=3, label="Diff")

from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1, 1)) 
ax.yaxis.set_major_formatter(formatter)

ax.set_xlabel(r'TOF ($\mu s$)', fontsize=25)
ax.set_ylabel('Int. (a.u.)', fontsize=25)
ax.set_xlim([2300, 16000])
ax.set_xticks(np.arange(2300, 16800, 1500), fontsize=23)
ax.tick_params(axis='x', labelsize=20, length=10)
# ax.set_yticks(np.arange(0.5, 2.2, 0.2), fontsize=23)
ax.yaxis.offsetText.set_fontsize(20)
ax.tick_params(axis='y', labelsize=20, length=10)
ax.legend(loc='upper left', bbox_to_anchor=(0.02, 0.98), frameon=False, fontsize="xx-large")
plt.tight_layout()
fig.canvas.header_visible = False
plt.show()
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %% [markdown]
# # Bank-5 Pawley Refinement

# %%
with open("./dia_bank_5_x_ycalc.dat", "r") as f:
    x, y_calc = np.loadtxt(f, unpack=True)
with open("./dia_bank_5_x_yobs.dat", "r") as f:
    x, y_obs = np.loadtxt(f, unpack=True)

y_diff = y_calc - y_obs - 2E5

fig, ax = plt.subplots(figsize=(12, 8))
ax.plot(x, y_obs, 'bo', markersize=5, label="Yobs")
ax.plot(x, y_calc, 'r-', linewidth=3, label="Ycalc")
ax.plot(x, y_diff, 'g-', linewidth=3, label="Diff")

from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1, 1)) 
ax.yaxis.set_major_formatter(formatter)

ax.set_xlabel(r'TOF ($\mu s$)', fontsize=25)
ax.set_ylabel('Int. (a.u.)', fontsize=25)
ax.set_xlim([2300, 14000])
ax.set_xticks(np.arange(2300, 14000, 1500), fontsize=23)
ax.tick_params(axis='x', labelsize=20, length=10)
# ax.set_yticks(np.arange(0.5, 2.2, 0.2), fontsize=23)
ax.yaxis.offsetText.set_fontsize(20)
ax.tick_params(axis='y', labelsize=20, length=10)
ax.legend(loc='upper left', bbox_to_anchor=(0.02, 0.98), frameon=False, fontsize="xx-large")
plt.tight_layout()
fig.canvas.header_visible = False
plt.show()
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…
